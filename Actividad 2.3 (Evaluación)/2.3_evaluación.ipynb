# %% [markdown]
# # Evaluación 1

# %%
import pandas as pd

# %%
#df = pd.read_csv('Florencia.csv')
df = pd.read_csv('Florencia.csv', index_col=0)
df
# Out:
#                                                           listing_url  \
# id
# 31840                              https://www.airbnb.com/rooms/31840
# 32120                              https://www.airbnb.com/rooms/32120
# 32180                              https://www.airbnb.com/rooms/32180
# 39115                              https://www.airbnb.com/rooms/39115
# 39165                              https://www.airbnb.com/rooms/39165
# ...                                                               ...
# 1244899380239866505  https://www.airbnb.com/rooms/1244899380239866505
# 1245523314672846496  https://www.airbnb.com/rooms/1245523314672846496
# 1245670462241721407  https://www.airbnb.com/rooms/1245670462241721407
# 1246427901403972447  https://www.airbnb.com/rooms/1246427901403972447
# 1246524294230158075  https://www.airbnb.com/rooms/1246524294230158075
#
#                           scrape_id last_scraped           source  \
# id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12722 entries, 31840 to 1246524294230158075
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_url                                   12722 non-null  object
#  1   scrape_id                                     12722 non-null  int64
#  2   last_scraped                                  12722 non-null  object
#  3   source                                        12722 non-null  object
#  4   name                                          12722 non-null  object
#  5   description                                   12357 non-null  object
#  6   neighborhood_overview                         7415 non-null   object
#  7   picture_url                                   12722 non-null  object
#  8   host_id                                       12722 non-null  int64
# ...

# %%
# Filtro A
# a) los registros de 5 "host name" diferentes

# obtener una lista de 5 nombres únicos de "host_name"
nombres_unicos = df['host_name'].dropna().unique()[:5]  # Seleccionamos los primeros 5 únicos

# filtrar el DataFrame para incluir solo registros de esos nombres
filtro1 = df[df['host_name'].isin(nombres_unicos)]
filtro1.to_csv('filtro1.csv')
filtro1
# Out:
#                                                           listing_url  \
# id
# 31840                              https://www.airbnb.com/rooms/31840
# 32120                              https://www.airbnb.com/rooms/32120
# 32180                              https://www.airbnb.com/rooms/32180
# 39115                              https://www.airbnb.com/rooms/39115
# 39165                              https://www.airbnb.com/rooms/39165
# ...                                                               ...
# 1228963644585619136  https://www.airbnb.com/rooms/1228963644585619136
# 1233265013842767183  https://www.airbnb.com/rooms/1233265013842767183
# 1233269999943788013  https://www.airbnb.com/rooms/1233269999943788013
# 1233953320344697177  https://www.airbnb.com/rooms/1233953320344697177
# 1236937521894400807  https://www.airbnb.com/rooms/1236937521894400807
#
#                           scrape_id last_scraped           source  \
# id
# ...

# %%
# Filtro B
# b) Los registros de los hosts que se hallan unido a Airbnb "antes del año 2019".

filtro2 = df[df['host_since'] < '2019-01-01']
filtro2.to_csv('filtro2.csv')
filtro2
# Out:
#                                                           listing_url  \
# id
# 31840                              https://www.airbnb.com/rooms/31840
# 32120                              https://www.airbnb.com/rooms/32120
# 32180                              https://www.airbnb.com/rooms/32180
# 39115                              https://www.airbnb.com/rooms/39115
# 39165                              https://www.airbnb.com/rooms/39165
# ...                                                               ...
# 1242707914051864985  https://www.airbnb.com/rooms/1242707914051864985
# 1243571765587292751  https://www.airbnb.com/rooms/1243571765587292751
# 1244707718502832322  https://www.airbnb.com/rooms/1244707718502832322
# 1244899380239866505  https://www.airbnb.com/rooms/1244899380239866505
# 1245523314672846496  https://www.airbnb.com/rooms/1245523314672846496
#
#                           scrape_id last_scraped           source  \
# id
# ...

# %%
# Filtro C
# c) Los registros de los hosts que responden "a más tardar en 1 día".
filtro3 = df[df['host_response_time'] == 'within a day']
filtro3.to_csv('filtro3.csv')
filtro3
# Out:
#                                                           listing_url  \
# id
# 47498                              https://www.airbnb.com/rooms/47498
# 81606                              https://www.airbnb.com/rooms/81606
# 81897                              https://www.airbnb.com/rooms/81897
# 82478                              https://www.airbnb.com/rooms/82478
# 82496                              https://www.airbnb.com/rooms/82496
# ...                                                               ...
# 1213058529134311769  https://www.airbnb.com/rooms/1213058529134311769
# 1217353448217271199  https://www.airbnb.com/rooms/1217353448217271199
# 1223751798102583568  https://www.airbnb.com/rooms/1223751798102583568
# 1236206599317566237  https://www.airbnb.com/rooms/1236206599317566237
# 1241270935036562865  https://www.airbnb.com/rooms/1241270935036562865
#
#                           scrape_id last_scraped       source  \
# id
# ...

# %%
# Filtro D
# d) Los registros que tengan "al menos 5 accommodates".
filtro4 = df[df['accommodates'] >= 5]
filtro4.to_csv('filtro4.csv')
filtro4
# Out:
#                                                           listing_url  \
# id
# 57767                              https://www.airbnb.com/rooms/57767
# 66353                              https://www.airbnb.com/rooms/66353
# 66598                              https://www.airbnb.com/rooms/66598
# 75803                              https://www.airbnb.com/rooms/75803
# 80693                              https://www.airbnb.com/rooms/80693
# ...                                                               ...
# 1242491792017676173  https://www.airbnb.com/rooms/1242491792017676173
# 1244685148174663949  https://www.airbnb.com/rooms/1244685148174663949
# 1244729378759152796  https://www.airbnb.com/rooms/1244729378759152796
# 1244899380239866505  https://www.airbnb.com/rooms/1244899380239866505
# 1245523314672846496  https://www.airbnb.com/rooms/1245523314672846496
#
#                           scrape_id last_scraped       source  \
# id
# ...

# %%
# Filtro E
# e) Los registros de los tipos de cuarto: "Entire home" y "Private room".
filtro5 = df[df['room_type'].isin(['Entire home/apt', 'Private room'])]
filtro5.to_csv('filtro5.csv')
filtro5
# Out:
#                                                           listing_url  \
# id
# 31840                              https://www.airbnb.com/rooms/31840
# 32120                              https://www.airbnb.com/rooms/32120
# 32180                              https://www.airbnb.com/rooms/32180
# 39115                              https://www.airbnb.com/rooms/39115
# 39165                              https://www.airbnb.com/rooms/39165
# ...                                                               ...
# 1244899380239866505  https://www.airbnb.com/rooms/1244899380239866505
# 1245523314672846496  https://www.airbnb.com/rooms/1245523314672846496
# 1245670462241721407  https://www.airbnb.com/rooms/1245670462241721407
# 1246427901403972447  https://www.airbnb.com/rooms/1246427901403972447
# 1246524294230158075  https://www.airbnb.com/rooms/1246524294230158075
#
#                           scrape_id last_scraped           source  \
# id
# ...

# %%
# Filtro F
# f) Los registros que "a lo mucho cuenten con 4 camas".
filtro6 = df[df['beds'] <= 4]   
filtro6.to_csv('filtro6.csv')
filtro6
# Out:
#                                                           listing_url  \
# id
# 32120                              https://www.airbnb.com/rooms/32120
# 32180                              https://www.airbnb.com/rooms/32180
# 39115                              https://www.airbnb.com/rooms/39115
# 39822                              https://www.airbnb.com/rooms/39822
# 43369                              https://www.airbnb.com/rooms/43369
# ...                                                               ...
# 1244899380239866505  https://www.airbnb.com/rooms/1244899380239866505
# 1245523314672846496  https://www.airbnb.com/rooms/1245523314672846496
# 1245670462241721407  https://www.airbnb.com/rooms/1245670462241721407
# 1246427901403972447  https://www.airbnb.com/rooms/1246427901403972447
# 1246524294230158075  https://www.airbnb.com/rooms/1246524294230158075
#
#                           scrape_id last_scraped       source  \
# id
# ...

# %%
# Filtro G
# g) Los registros que "tengan 1 baño o que sean superhost" pero con la condición de que "todos sean instant_bookable".
filtro7 = df[((df['bathrooms'] == 1) | (df['host_is_superhost'] == 't')) & (df['instant_bookable'] == 't')]
filtro7.to_csv('filtro7.csv')
filtro7
# Out:
#                                                           listing_url  \
# id
# 43369                              https://www.airbnb.com/rooms/43369
# 46520                              https://www.airbnb.com/rooms/46520
# 46524                              https://www.airbnb.com/rooms/46524
# 52545                              https://www.airbnb.com/rooms/52545
# 57572                              https://www.airbnb.com/rooms/57572
# ...                                                               ...
# 1243233327663624636  https://www.airbnb.com/rooms/1243233327663624636
# 1244074282766815361  https://www.airbnb.com/rooms/1244074282766815361
# 1244729378759152796  https://www.airbnb.com/rooms/1244729378759152796
# 1245523314672846496  https://www.airbnb.com/rooms/1245523314672846496
# 1246524294230158075  https://www.airbnb.com/rooms/1246524294230158075
#
#                           scrape_id last_scraped       source  \
# id
# ...

# %%
# Filtro H
# h) Los registros cuyo "review_scores_cleanliness sea menor de 3 y review_scores_rating sea mayor de 3".
filtro8 = df[(df['review_scores_cleanliness'] < 3) & (df['review_scores_rating'] > 3)]
filtro8.to_csv('filtro8.csv')
filtro8
# Out:
#                                                           listing_url  \
# id
# 4196248                          https://www.airbnb.com/rooms/4196248
# 51415722                        https://www.airbnb.com/rooms/51415722
# 53371818                        https://www.airbnb.com/rooms/53371818
# 1096145736922326382  https://www.airbnb.com/rooms/1096145736922326382
# 1130960168236326078  https://www.airbnb.com/rooms/1130960168236326078
# 1148355041035996152  https://www.airbnb.com/rooms/1148355041035996152
# 1173071202137058564  https://www.airbnb.com/rooms/1173071202137058564
# 1174043352700835244  https://www.airbnb.com/rooms/1174043352700835244
#
#                           scrape_id last_scraped           source  \
# id
# 4196248              20240917031426   2024-09-17      city scrape
# 51415722             20240917031426   2024-09-17      city scrape
# 53371818             20240917031426   2024-09-17  previous scrape
# ...
